# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -qq faiss-cpu
# !pip install -qq transformers
# !pip install -qq tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 69.2 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn.functional as F
import faiss
from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm

# %%
data_path = "/content/drive/MyDrive/Data Science Projects/Machine Learning Projects/Email_classification/2cls_spam_text_cls.csv"
data = pd.read_csv(data_path)
data.head(5)
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
messages = data["Message"].values.tolist()
labels = data["Category"].values.tolist()

# %%
Model_Name = "intfloat/multilingual-e5-base"
tokenizer = AutoTokenizer.from_pretrained(Model_Name)
model = AutoModel.from_pretrained(Model_Name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)/content/drive/MyDrive/Data Science Projects/Machine Learning Projects/Email_classification/
model.eval()

def average_pool(last_hidden_states, attention_mask):
  last_hidden = last_hidden_states.masked_fill(
      ~attention_mask[..., None].bool(), 0.0
  )
  return last_hidden.sum(dim=1)/attention_mask.sum(dim=1)[..., None]
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]

# %%
def get_embeddings(texts, model, tokenizer, device, batch_size=32):
  embeddings = []
  for i in tqdm(range(0, len(texts), batch_size), desc="Generating embeddings"):
    batch_texts = texts[i:i+batch_size]
    batch_texts_with_prefix = [f"passage: {text}" for text in batch_texts]

    batch_dict = tokenizer(batch_texts_with_prefix, max_length=512, padding=True, truncation=True, return_tensors='pt')
    batch_dict = {k: v.to(device) for k,v, in batch_dict.items()}

    with torch.no_grad():
      outputs = model(**batch_dict)
      batch_embeddings = average_pool(outputs.last_hidden_state, batch_dict["attention_mask"])
      batch_embeddings = F.normalize(batch_embeddings, p=2, dim=1)
      embeddings.append(batch_embeddings.cpu().numpy())

  return np.vstack(embeddings)


lb = LabelEncoder()
y = lb.fit_transform(labels)

X_embeddings = get_embeddings(messages, model, tokenizer, device)

metadata = [{"index":i, "message":message, "label":label, "label_encoded":y[i]}
            for i, (message, label) in enumerate(zip(messages, labels))]
# Out:
# Generating embeddings:   0%|          | 0/175 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Generating embeddings: 100%|██████████| 175/175 [00:21<00:00,  8.08it/s]

# %%
metadata
# Out:
# [{'index': 0,
#   'message': 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1,
#   'message': 'Ok lar... Joking wif u oni...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2,
#   'message': "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3,
#   'message': 'U dun say so early hor... U c already then say...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4,
#   'message': "Nah I don't think he goes to usf, he lives around here though",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5,
#   'message': "FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv",
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 6,
#   'message': 'Even my brother is not like to speak with me. They treat me like aids patent.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 7,
#   'message': "As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 8,
#   'message': 'WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 9,
#   'message': 'Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with camera for Free! Call The Mobile Update Co FREE on 08002986030',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 10,
#   'message': "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 11,
#   'message': 'SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 12,
#   'message': 'URGENT! You have won a 1 week FREE membership in our £100,000 Prize Jackpot! Txt the word: CLAIM to No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 13,
#   'message': "I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 14,
#   'message': 'I HAVE A DATE ON SUNDAY WITH WILL!!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 15,
#   'message': 'XXXMobileMovieClub: To use your credit, click the WAP link in the next txt message or click here>> http://wap. xxxmobilemovieclub.com?n=QJKGIGHJJGCBL',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 16,
#   'message': "Oh k...i'm watching here:)",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 17,
#   'message': 'Eh u remember how 2 spell his name... Yes i did. He v naughty make until i v wet.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 18,
#   'message': 'Fine if that\x92s the way u feel. That\x92s the way its gota b',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 19,
#   'message': 'England v Macedonia - dont miss the goals/team news. Txt ur national team to 87077 eg ENGLAND to 87077 Try:WALES, SCOTLAND 4txt/ú1.20 POBOXox36504W45WQ 16+',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 20,
#   'message': 'Is that seriously how you spell his name?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 21,
#   'message': 'I‘m going to try for 2 months ha ha only joking',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 22,
#   'message': 'So ü pay first lar... Then when is da stock comin...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 23,
#   'message': 'Aft i finish my lunch then i go str down lor. Ard 3 smth lor. U finish ur lunch already?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 24,
#   'message': 'Ffffffffff. Alright no way I can meet up with you sooner?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 25,
#   'message': "Just forced myself to eat a slice. I'm really not hungry tho. This sucks. Mark is getting worried. He knows I'm sick when I turn down pizza. Lol",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 26,
#   'message': 'Lol your always so convincing.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 27,
#   'message': "Did you catch the bus ? Are you frying an egg ? Did you make a tea? Are you eating your mom's left over dinner ? Do you feel my Love ?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 28,
#   'message': "I'm back &amp; we're packing the car now, I'll let you know if there's room",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 29,
#   'message': 'Ahhh. Work. I vaguely remember that! What does it feel like? Lol',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 30,
#   'message': "Wait that's still not all that clear, were you not sure about me being sarcastic or that that's why x doesn't want to live with us",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 31,
#   'message': "Yeah he got in at 2 and was v apologetic. n had fallen out and she was actin like spoilt child and he got caught up in that. Till 2! But we won't go there! Not doing too badly cheers. You?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 32,
#   'message': 'K tell me anything about you.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 33,
#   'message': 'For fear of fainting with the of all that housework you just did? Quick have a cuppa',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 34,
#   'message': 'Thanks for your subscription to Ringtone UK your mobile will be charged £5/month Please confirm by replying YES or NO. If you reply NO you will not be charged',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 35,
#   'message': 'Yup... Ok i go home look at the timings then i msg ü again... Xuhui going to learn on 2nd may too but her lesson is at 8am',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 36,
#   'message': "Oops, I'll let you know when my roommate's done",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 37,
#   'message': 'I see the letter B on my car',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 38,
#   'message': 'Anything lor... U decide...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 39,
#   'message': "Hello! How's you and how did saturday go? I was just texting to see if you'd decided to do anything tomo. Not that i'm trying to invite myself or anything!",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 40,
#   'message': 'Pls go ahead with watts. I just wanted to be sure. Do have a great weekend. Abiola',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 41,
#   'message': 'Did I forget to tell you ? I want you , I need you, I crave you ... But most of all ... I love you my sweet Arabian steed ... Mmmmmm ... Yummy',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 42,
#   'message': '07732584351 - Rodger Burns - MSG = We tried to call you re your reply to our sms for a free nokia mobile + free camcorder. Please call now 08000930705 for delivery tomorrow',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 43,
#   'message': 'WHO ARE YOU SEEING?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 44,
#   'message': 'Great! I hope you like your man well endowed. I am  &lt;#&gt;  inches...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 45,
#   'message': 'No calls..messages..missed calls',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 46,
#   'message': "Didn't you get hep b immunisation in nigeria.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 47,
#   'message': 'Fair enough, anything going on?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 48,
#   'message': "Yeah hopefully, if tyler can't do it I could maybe ask around a bit",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 49,
#   'message': "U don't know how stubborn I am. I didn't even want to go to the hospital. I kept telling Mark I'm not a weak sucker. Hospitals are for weak suckers.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 50,
#   'message': 'What you thinked about me. First time you saw me in class.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 51,
#   'message': 'A gram usually runs like  &lt;#&gt; , a half eighth is smarter though and gets you almost a whole second gram for  &lt;#&gt;',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 52,
#   'message': "K fyi x has a ride early tomorrow morning but he's crashing at our place tonight",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 53,
#   'message': 'Wow. I never realized that you were so embarassed by your accomodations. I thought you liked it, since i was doing the best i could and you always seemed so happy about "the cave". I\'m sorry I didn\'t and don\'t have more to give. I\'m sorry i offered. I\'m sorry your room was so embarassing.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 54,
#   'message': 'SMS. ac Sptv: The New Jersey Devils and the Detroit Red Wings play Ice Hockey. Correct or Incorrect? End? Reply END SPTV',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 55,
#   'message': 'Do you know what Mallika Sherawat did yesterday? Find out now @  &lt;URL&gt;',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 56,
#   'message': 'Congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! C Suprman V, Matrix3, StarWars3, etc all 4 FREE! bx420-ip4-5we. 150pm. Dont miss out!',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 57,
#   'message': "Sorry, I'll call later in meeting.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 58,
#   'message': 'Tell where you reached',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 59,
#   'message': 'Yes..gauti and sehwag out of odi series.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 60,
#   'message': "Your gonna have to pick up a $1 burger for yourself on your way home. I can't even move. Pain is killing me.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 61,
#   'message': 'Ha ha ha good joke. Girls are situation seekers.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 62,
#   'message': 'Its a part of checking IQ',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 63,
#   'message': 'Sorry my roommates took forever, it ok if I come by now?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 64,
#   'message': 'Ok lar i double check wif da hair dresser already he said wun cut v short. He said will cut until i look nice.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 65,
#   'message': 'As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a £1500 Bonus Prize, call 09066364589',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 66,
#   'message': 'Today is "song dedicated day.." Which song will u dedicate for me? Send this to all ur valuable frnds but first rply me...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 67,
#   'message': 'Urgent UR awarded a complimentary trip to EuroDisinc Trav, Aco&Entry41 Or £1000. To claim txt DIS to 87121 18+6*£1.50(moreFrmMob. ShrAcomOrSglSuplt)10, LS1 3AJ',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 68,
#   'message': 'Did you hear about the new "Divorce Barbie"? It comes with all of Ken\'s stuff!',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 69,
#   'message': 'I plane to give on this month end.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 70,
#   'message': 'Wah lucky man... Then can save money... Hee...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 71,
#   'message': 'Finished class where are you.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 72,
#   'message': 'HI BABE IM AT HOME NOW WANNA DO SOMETHING? XX',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 73,
#   'message': 'K..k:)where are you?how did you performed?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 74,
#   'message': 'U can call me now...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 75,
#   'message': 'I am waiting machan. Call me once you free.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 76,
#   'message': 'Thats cool. i am a gentleman and will treat you with dignity and respect.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 77,
#   'message': 'I like you peoples very much:) but am very shy pa.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 78,
#   'message': 'Does not operate after  &lt;#&gt;  or what',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 79,
#   'message': "Its not the same here. Still looking for a job. How much do Ta's earn there.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 80,
#   'message': "Sorry, I'll call later",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 81,
#   'message': 'K. Did you call me just now ah?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 82,
#   'message': 'Ok i am on the way to home hi hi',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 83,
#   'message': 'You will be in the place of that man',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 84,
#   'message': 'Yup next stop.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 85,
#   'message': "I call you later, don't have network. If urgnt, sms me.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 86,
#   'message': "For real when u getting on yo? I only need 2 more tickets and one more jacket and I'm done. I already used all my multis.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 87,
#   'message': "Yes I started to send requests to make it but pain came back so I'm back in bed. Double coins at the factory too. I gotta cash in all my nitros.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 88,
#   'message': "I'm really not up to it still tonight babe",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 89,
#   'message': 'Ela kano.,il download, come wen ur free..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 90,
#   'message': 'Yeah do! Don‘t stand to close tho- you‘ll catch something!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 91,
#   'message': "Sorry to be a pain. Is it ok if we meet another night? I spent late afternoon in casualty and that means i haven't done any of y stuff42moro and that includes all my time sheets and that. Sorry.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 92,
#   'message': 'Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz SOMEONE still Loves to see u Smiling!!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 93,
#   'message': 'Please call our customer service representative on 0800 169 6031 between 10am-9pm as you have WON a guaranteed £1000 cash or £5000 prize!',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 94,
#   'message': 'Havent planning to buy later. I check already lido only got 530 show in e afternoon. U finish work already?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 95,
#   'message': 'Your free ringtone is waiting to be collected. Simply text the password "MIX" to 85069 to verify. Get Usher and Britney. FML, PO Box 5249, MK17 92H. 450Ppw 16',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 96,
#   'message': 'Watching telugu movie..wat abt u?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 97,
#   'message': 'i see. When we finish we have loads of loans to pay',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 98,
#   'message': 'Hi. Wk been ok - on hols now! Yes on for a bit of a run. Forgot that i have hairdressers appointment at four so need to get home n shower beforehand. Does that cause prob for u?"',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 99,
#   'message': 'I see a cup of coffee animation',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 100,
#   'message': "Please don't text me anymore. I have nothing else to say.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 101,
#   'message': 'Okay name ur price as long as its legal! Wen can I pick them up? Y u ave x ams xx',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 102,
#   'message': "I'm still looking for a car to buy. And have not gone 4the driving test yet.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 103,
#   'message': "As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 104,
#   'message': "wow. You're right! I didn't mean to do that. I guess once i gave up on boston men and changed my search location to nyc, something changed. Cuz on my signin page it still says boston.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 105,
#   'message': 'Umma my life and vava umma love you lot dear',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 106,
#   'message': 'Thanks a lot for your wishes on my birthday. Thanks you for making my birthday truly memorable.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 107,
#   'message': "Aight, I'll hit you up when I get some cash",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 108,
#   'message': "How would my ip address test that considering my computer isn't a minecraft server",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 109,
#   'message': 'I know! Grumpy old people. My mom was like you better not be lying. Then again I am always the one to play jokes...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 110,
#   'message': "Dont worry. I guess he's busy.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 111,
#   'message': 'What is the plural of the noun research?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 112,
#   'message': 'Going for dinner.msg you after.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 113,
#   'message': "I'm ok wif it cos i like 2 try new things. But i scared u dun like mah. Cos u said not too loud.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 114,
#   'message': 'GENT! We are trying to contact you. Last weekends draw shows that you won a £1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 115,
#   'message': "Wa, ur openin sentence very formal... Anyway, i'm fine too, juz tt i'm eatin too much n puttin on weight...Haha... So anythin special happened?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 116,
#   'message': "As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 117,
#   'message': 'You are a winner U have been specially selected 2 receive £1000 or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810910p/min (18+)',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 118,
#   'message': 'Goodo! Yes we must speak friday - egg-potato ratio for tortilla needed!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 119,
#   'message': "Hmm...my uncle just informed me that he's paying the school directly. So pls buy food.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 120,
#   'message': 'PRIVATE! Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points. To claim call 08719180248 Identifier Code: 45239 Expires',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 121,
#   'message': 'URGENT! Your Mobile No. was awarded £2000 Bonus Caller Prize on 5/9/03 This is our final try to contact U! Call from Landline 09064019788 BOX42WR29C, 150PPM',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 122,
#   'message': 'here is my new address -apples&pairs&all that malarky',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 123,
#   'message': 'Todays Voda numbers ending 7548 are selected to receive a $350 award. If you have a match please call 08712300220 quoting claim code 4041 standard rates app',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 124,
#   'message': 'I am going to sao mu today. Will be done only at 12',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 125,
#   'message': "Ü predict wat time ü'll finish buying?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 126,
#   'message': 'Good stuff, will do.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 127,
#   'message': "Just so that you know,yetunde hasn't sent money yet. I just sent her a text not to bother sending. So its over, you dont have to involve yourself in anything. I shouldn't have imposed anything on you in the first place so for that, i apologise.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 128,
#   'message': 'Are you there in room.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 129,
#   'message': 'HEY GIRL. HOW R U? HOPE U R WELL ME AN DEL R BAK! AGAIN LONG TIME NO C! GIVE ME A CALL SUM TIME FROM LUCYxx',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 130,
#   'message': 'K..k:)how much does it cost?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 131,
#   'message': "I'm home.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 132,
#   'message': 'Dear, will call Tmorrow.pls accomodate.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 133,
#   'message': 'First answer my question.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 134,
#   'message': 'Sunshine Quiz Wkly Q! Win a top Sony DVD player if u know which country the Algarve is in? Txt ansr to 82277. £1.50 SP:Tyrone',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 135,
#   'message': "Want 2 get laid tonight? Want real Dogging locations sent direct 2 ur mob? Join the UK's largest Dogging Network bt Txting GRAVEL to 69888! Nt. ec2a. 31p.msg@150p",
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 136,
#   'message': "I only haf msn. It's yijue@hotmail.com",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 137,
#   'message': 'He is there. You call and meet him',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 138,
#   'message': 'No no. I will check all rooms befor activities',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 139,
#   'message': "You'll not rcv any more msgs from the chat svc. For FREE Hardcore services text GO to: 69988 If u get nothing u must Age Verify with yr network & try again",
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 140,
#   'message': 'Got c... I lazy to type... I forgot ü in lect... I saw a pouch but like not v nice...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 141,
#   'message': "K, text me when you're on the way",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 142,
#   'message': 'Sir, Waiting for your mail.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 143,
#   'message': 'A swt thought: "Nver get tired of doing little things 4 lovable persons.." Coz..somtimes those little things occupy d biggest part in their Hearts.. Gud ni8',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 144,
#   'message': 'I know you are. Can you pls open the back?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 145,
#   'message': 'Yes see ya not on the dot',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 146,
#   'message': 'Whats the staff name who is taking class for us?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 147,
#   'message': "FreeMsg Why haven't you replied to my text? I'm Randy, sexy, female and live local. Luv to hear from u. Netcollex Ltd 08700621170150p per msg reply Stop to end",
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 148,
#   'message': 'Ummma.will call after check in.our life will begin from qatar so pls pray very hard.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 149,
#   'message': 'K..i deleted my contact that why?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 150,
#   'message': 'Sindu got job in birla soft ..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 151,
#   'message': "The wine is flowing and i'm i have nevering..",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 152,
#   'message': 'Yup i thk cine is better cos no need 2 go down 2 plaza mah.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 153,
#   'message': 'Ok... Ur typical reply...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 154,
#   'message': "As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 155,
#   'message': 'You are everywhere dirt, on the floor, the windows, even on my shirt. And sometimes when i open my mouth, you are all that comes flowing out. I dream of my world without you, then half my chores are out too. A time of joy for me, lots of tv shows i.ll see. But i guess like all things you just must exist, like rain, hail and mist, and when my time here is done, you and i become one.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 156,
#   'message': 'Aaooooright are you at work?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 157,
#   'message': "I'm leaving my house now...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 158,
#   'message': 'Hello, my love. What are you doing? Did you get to that interview today? Are you you happy? Are you being a good boy? Do you think of me?Are you missing me ?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 159,
#   'message': 'Customer service annoncement. You have a New Years delivery waiting for you. Please call 07046744435 now to arrange delivery',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 160,
#   'message': 'You are a winner U have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 161,
#   'message': "Keep yourself safe for me because I need you and I miss you already and I envy everyone that see's you in real life",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 162,
#   'message': 'New car and house for my parents.:)i have only new job in hand:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 163,
#   'message': "I'm so in love with you. I'm excited each day i spend with you. You make me so happy.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 164,
#   'message': '-PLS STOP bootydelious (32/F) is inviting you to be her friend. Reply YES-434 or NO-434 See her: www.SMS.ac/u/bootydelious STOP? Send STOP FRND to 62468',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 165,
#   'message': 'BangBabes Ur order is on the way. U SHOULD receive a Service Msg 2 download UR content. If U do not, GoTo wap. bangb. tv on UR mobile internet/service menu',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 166,
#   'message': 'I place all ur points on e cultures module already.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 167,
#   'message': 'URGENT! We are trying to contact you. Last weekends draw shows that you have won a £900 prize GUARANTEED. Call 09061701939. Claim code S89. Valid 12hrs only',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 168,
#   'message': "Hi frnd, which is best way to avoid missunderstding wit our beloved one's?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 169,
#   'message': 'Great escape. I fancy the bridge but needs her lager. See you tomo',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 170,
#   'message': 'Yes :)it completely in out of form:)clark also utter waste.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 171,
#   'message': 'Sir, I need AXIS BANK account no and bank address.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 172,
#   'message': 'Hmmm.. Thk sure got time to hop ard... Ya, can go 4 free abt... Muz call u to discuss liao...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 173,
#   'message': 'What time you coming down later?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 174,
#   'message': 'Bloody hell, cant believe you forgot my surname Mr . Ill give u a clue, its spanish and begins with m...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 175,
#   'message': "Well, i'm gonna finish my bath now. Have a good...fine night.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 176,
#   'message': "Let me know when you've got the money so carlos can make the call",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 177,
#   'message': 'U still going to the mall?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 178,
#   'message': "Turns out my friends are staying for the whole show and won't be back til ~ &lt;#&gt; , so feel free to go ahead and smoke that $ &lt;#&gt;  worth",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 179,
#   'message': 'Text her. If she doesnt reply let me know so i can have her log in',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 180,
#   'message': "Hi! You just spoke to MANEESHA V. We'd like to know if you were satisfied with the experience. Reply Toll Free with Yes or No.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 181,
#   'message': 'You lifted my hopes with the offer of money. I am in need. Especially when the end of the month approaches and it hurts my studying. Anyways have a gr8 weekend',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 182,
#   'message': 'Lol no. U can trust me.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 183,
#   'message': 'ok. I am a gentleman and will treat you with dignity and respect.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 184,
#   'message': 'He will, you guys close?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 185,
#   'message': 'Going on nothing great.bye',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 186,
#   'message': "Hello handsome ! Are you finding that job ? Not being lazy ? Working towards getting back that net for mummy ? Where's my boytoy now ? Does he miss me ?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 187,
#   'message': 'Haha awesome, be there in a minute',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 188,
#   'message': 'Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed £1000 cash or £5000 prize!',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 189,
#   'message': 'Have you got Xmas radio times. If not i will get it now',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 190,
#   'message': 'I jus reached home. I go bathe first. But my sis using net tell u when she finishes k...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 191,
#   'message': 'Are you unique enough? Find out from 30th August. www.areyouunique.co.uk',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 192,
#   'message': "I'm sorry. I've joined the league of people that dont keep in touch. You mean a great deal to me. You have been a friend at all times even at great personal cost. Do have a great week.|",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 193,
#   'message': 'Hi :)finally i completed the course:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 194,
#   'message': 'It will stop on itself. I however suggest she stays with someone that will be able to give ors for every stool.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 195,
#   'message': "How are you doing? Hope you've settled in for the new school year. Just wishin you a gr8 day",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 196,
#   'message': 'Gud mrng dear hav a nice day',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 197,
#   'message': 'Did u got that persons story',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 198,
#   'message': 'is your hamster dead? Hey so tmr i meet you at 1pm orchard mrt?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 199,
#   'message': 'Hi its Kate how is your evening? I hope i can see you tomorrow for a bit but i have to bloody babyjontet! Txt back if u can. :) xxx',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 200,
#   'message': 'Found it, ENC  &lt;#&gt; , where you at?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 201,
#   'message': 'I sent you  &lt;#&gt;  bucks',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 202,
#   'message': 'Hello darlin ive finished college now so txt me when u finish if u can love Kate xxx',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 203,
#   'message': 'Your account has been refilled successfully by INR  &lt;DECIMAL&gt; . Your KeralaCircle prepaid account balance is Rs  &lt;DECIMAL&gt; . Your Transaction ID is KR &lt;#&gt; .',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 204,
#   'message': 'Goodmorning sleeping ga.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 205,
#   'message': 'U call me alter at 11 ok.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 206,
#   'message': 'Ü say until like dat i dun buy ericsson oso cannot oredi lar...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 207,
#   'message': "As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 208,
#   'message': 'Aight yo, dats straight dogg',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 209,
#   'message': 'You please give us connection today itself before  &lt;DECIMAL&gt;  or refund the bill',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 210,
#   'message': 'Both :) i shoot big loads so get ready!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 211,
#   'message': "What's up bruv, hope you had a great break. Do have a rewarding semester.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 212,
#   'message': 'Home so we can always chat',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 213,
#   'message': 'K:)k:)good:)study well.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 214,
#   'message': 'Yup... How ü noe leh...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 215,
#   'message': 'Sounds great! Are you home now?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 216,
#   'message': 'Finally the match heading towards draw as your prediction.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 217,
#   'message': "Tired. I haven't slept well the past few nights.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 218,
#   'message': 'Easy ah?sen got selected means its good..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 219,
#   'message': 'I have to take exam with march 3',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 220,
#   'message': "Yeah you should. I think you can use your gt atm now to register. Not sure but if there's anyway i can help let me know. But when you do be sure you are ready.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 221,
#   'message': 'Ok no prob. Take ur time.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 222,
#   'message': 'There is os called ubandu which will run without installing in hard disk...you can use that os to copy the important files in system and give it to repair shop..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 223,
#   'message': "Sorry, I'll call later",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 224,
#   'message': 'U say leh... Of course nothing happen lar. Not say v romantic jus a bit only lor. I thk e nite scenery not so nice leh.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 225,
#   'message': '500 New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today!From ONLY £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 226,
#   'message': 'Would really appreciate if you call me. Just need someone to talk to.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 227,
#   'message': 'Will u meet ur dream partner soon? Is ur career off 2 a flyng start? 2 find out free, txt HORO followed by ur star sign, e. g. HORO ARIES',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 228,
#   'message': 'Hey company elama po mudyadhu.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 229,
#   'message': 'Life is more strict than teacher... Bcoz Teacher teaches lesson &amp; then conducts exam, But Life first conducts Exam &amp; then teaches Lessons. Happy morning. . .',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 230,
#   'message': 'Dear good morning now only i am up',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 231,
#   'message': 'Get down in gandhipuram and walk to cross cut road. Right side &lt;#&gt; street road and turn at first right.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 232,
#   'message': 'Dear we are going to our rubber place',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 233,
#   'message': "Sorry battery died, yeah I'm here",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 234,
#   'message': 'Yes:)here tv is always available in work place..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 235,
#   'message': 'Text & meet someone sexy today. U can find a date or even flirt its up to U. Join 4 just 10p. REPLY with NAME & AGE eg Sam 25. 18 -msg recd@thirtyeight pence',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 236,
#   'message': 'I have printed it oh. So  &lt;#&gt;  come upstairs',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 237,
#   'message': 'Or ill be a little closer like at the bus stop on the same street',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 238,
#   'message': 'Where are you?when wil you reach here?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 239,
#   'message': "New Theory: Argument wins d SITUATION, but loses the PERSON. So dont argue with ur friends just.. . . . kick them &amp; say, I'm always correct.!",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 240,
#   'message': 'U 447801259231 have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094597',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 241,
#   'message': 'Tomarrow final hearing on my laptop case so i cant.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 242,
#   'message': 'PLEASSSSSSSEEEEEE TEL ME V AVENT DONE SPORTSx',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 243,
#   'message': 'Okay. No no, just shining on. That was meant to be signing, but that sounds better.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 244,
#   'message': "Although i told u dat i'm into baig face watches now but i really like e watch u gave cos it's fr u. Thanx 4 everything dat u've done today, i'm touched...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 245,
#   'message': "U don't remember that old commercial?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 246,
#   'message': "Too late. I said i have the website. I didn't i have or dont have the slippers",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 247,
#   'message': 'I asked you to call him now ok',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 248,
#   'message': 'Kallis wont bat in 2nd innings.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 249,
#   'message': 'It didnt work again oh. Ok goodnight then. I.ll fix and have it ready by the time you wake up. You are very dearly missed have a good night sleep.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 250,
#   'message': 'Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 251,
#   'message': 'Ranjith cal drpd Deeraj and deepak 5min hold',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 252,
#   'message': 'Wen ur lovable bcums angry wid u, dnt take it seriously.. Coz being angry is d most childish n true way of showing deep affection, care n luv!.. kettoda manda... Have nice day da.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 253,
#   'message': 'What you doing?how are you?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 254,
#   'message': 'Ups which is 3days also, and the shipping company that takes 2wks. The other way is usps which takes a week but when it gets to lag you may have to bribe nipost to get your stuff.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 255,
#   'message': "I'm back, lemme know when you're ready",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 256,
#   'message': "Don't necessarily expect it to be done before you get back though because I'm just now headin out",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 257,
#   'message': 'Mmm so yummy babe ... Nice jolt to the suzy',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 258,
#   'message': 'Where are you lover ? I need you ...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 259,
#   'message': 'We tried to contact you re your reply to our offer of a Video Handset? 750 anytime networks mins? UNLIMITED TEXT? Camcorder? Reply or call 08000930705 NOW',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 260,
#   'message': 'I‘m parked next to a MINI!!!! When are you coming in today do you think?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 261,
#   'message': 'Yup',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 262,
#   'message': "Anyway i'm going shopping on my own now. Cos my sis not done yet. Dun disturb u liao.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 263,
#   'message': 'MY NO. IN LUTON 0125698789 RING ME IF UR AROUND! H*',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 264,
#   'message': 'Hey I am really horny want to chat or see me naked text hot to 69698 text charged at 150pm to unsubscribe text stop 69698',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 265,
#   'message': 'Why you Dint come with us.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 266,
#   'message': 'Same. Wana plan a trip sometme then',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 267,
#   'message': 'Not sure yet, still trying to get a hold of him',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 268,
#   'message': 'Ur ringtone service has changed! 25 Free credits! Go to club4mobiles.com to choose content now! Stop? txt CLUB STOP to 87070. 150p/wk Club4 PO Box1146 MK45 2WT',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 269,
#   'message': 'The evo. I just had to download flash. Jealous?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 270,
#   'message': 'Ringtone Club: Get the UK singles chart on your mobile each week and choose any top quality ringtone! This message is free of charge.',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 271,
#   'message': "Come to mu, we're sorting out our narcotics situation",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 272,
#   'message': 'Night has ended for another day, morning has come in a special way. May you smile like the sunny rays and leaves your worries at the blue blue bay.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 273,
#   'message': 'HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 274,
#   'message': 'Usf I guess, might as well take 1 car',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 275,
#   'message': 'No objection. My bf not coming.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 276,
#   'message': 'Thanx...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 277,
#   'message': 'Tell rob to mack his gf in the theater',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 278,
#   'message': "Awesome, I'll see you in a bit",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 279,
#   'message': 'Just sent it. So what type of food do you like?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 280,
#   'message': 'All done? All handed in? Celebrations in full swing yet?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 281,
#   'message': 'You got called a tool?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 282,
#   'message': 'Wen u miss someone, the person is definitely special for u..... But if the person is so special, why to miss them, just Keep-in-touch gdeve..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 283,
#   'message': 'Ok. I asked for money how far',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 284,
#   'message': 'Okie...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 285,
#   'message': "Yeah I think my usual guy's still passed out from last night, if you get ahold of anybody let me know and I'll throw down",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 286,
#   'message': 'K, I might come by tonight then if my class lets out early',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 287,
#   'message': 'Ok..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 288,
# ...
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 904,
#   'message': "Lovely smell on this bus and it ain't tobacco...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 905,
#   'message': "We're all getting worried over here, derek and taylor have already assumed the worst",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 906,
#   'message': "Hey what's up charles sorry about the late reply.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 907,
#   'message': 'all the lastest from Stereophonics, Marley, Dizzee Racal, Libertines and The Strokes! Win Nookii games with Flirt!! Click TheMob WAP Bookmark or text WAP to 82468',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 908,
#   'message': 'I.ll give her once i have it. Plus she said grinule greet you whenever we speak',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 909,
#   'message': 'WHITE FUDGE OREOS ARE IN STORES',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 910,
#   'message': 'January Male Sale! Hot Gay chat now cheaper, call 08709222922. National rate from 1.5p/min cheap to 7.8p/min peak! To stop texts call 08712460324 (10p/min)',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 911,
#   'message': "My love ! How come it took you so long to leave for Zaher's? I got your words on ym and was happy to see them but was sad you had left. I miss you",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 912,
#   'message': 'I am sorry it hurt you.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 913,
#   'message': "Can't. I feel nauseous. I'm so pissed. I didn't eat any sweets all week cause today I was planning to pig out. I was dieting all week. And now I'm not hungry :/",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 914,
#   'message': 'Ok lor but not too early. Me still having project meeting now.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 915,
#   'message': 'Call me da, i am waiting for your call.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 916,
#   'message': 'I could ask carlos if we could get more if anybody else can chip in',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 917,
#   'message': 'Was actually about to send you a reminder today. Have a wonderful weekend',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 918,
#   'message': "When people see my msgs, They think Iam addicted to msging... They are wrong, Bcoz They don\\'t know that Iam addicted to my sweet Friends..!! BSLVYL",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 919,
#   'message': 'Hey you gave them your photo when you registered for driving ah? Tmr wanna meet at yck?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 920,
#   'message': 'Dont talk to him ever ok its my word.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 921,
#   'message': 'When u wana see it then',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 922,
#   'message': "On ma way to school. Can you pls send me ashley's number",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 923,
#   'message': 'It shall be fine. I have avalarr now. Will hollalater',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 924,
#   'message': "She went to attend another two rounds today..but still did't reach home..",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 925,
#   'message': 'Actually i deleted my old website..now i m blogging at magicalsongs.blogspot.com',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 926,
#   'message': 'K, wait chikku..il send aftr  &lt;#&gt; mins',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 927,
#   'message': "But I'm on a diet. And I ate 1 too many slices of pizza yesterday. Ugh I'm ALWAYS on a diet.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 928,
#   'message': 'K:)i will give my kvb acc details:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 929,
#   'message': 'Oh all have to come ah?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 930,
#   'message': 'money!!! you r a lucky winner ! 2 claim your prize text money 2 88600 over £1million to give away ! ppt150x3+normal text rate box403 w1t1jy',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 931,
#   'message': "I'm really sorry i won't b able 2 do this friday.hope u can find an alternative.hope yr term's going ok:-)",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 932,
#   'message': 'Congratulations ore mo owo re wa. Enjoy it and i wish you many happy moments to and fro wherever you go',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 933,
#   'message': 'So do you have samus shoulders yet',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 934,
#   'message': "What time you think you'll have it? Need to know when I should be near campus",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 935,
#   'message': 'Dear Matthew please call 09063440451 from a landline, your complimentary 4*Lux Tenerife holiday or £1000 CASH await collection. ppm150 SAE T&Cs Box334 SK38XH.',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 936,
#   'message': 'Then dun wear jeans lor...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 937,
#   'message': 'Since when, which side, any fever, any vomitin.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 938,
#   'message': 'K:)k.are you in college?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 939,
#   'message': 'Urgent! call 09061749602 from Landline. Your complimentary 4* Tenerife Holiday or £10,000 cash await collection SAE T&Cs BOX 528 HP20 1YF 150ppm 18+',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 940,
#   'message': 'Better. Made up for Friday and stuffed myself like a pig yesterday. Now I feel bleh. But at least its not writhing pain kind of bleh.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 941,
#   'message': "No we sell it all so we'll have tons if coins. Then sell our coins to someone thru paypal. Voila! Money back in life pockets:)",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 942,
#   'message': 'Theyre doing it to lots of places. Only hospitals and medical places are safe.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 943,
#   'message': 'How about getting in touch with folks waiting for company? Just txt back your NAME and AGE to opt in! Enjoy the community (150p/SMS)',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 944,
#   'message': "And also I've sorta blown him off a couple times recently so id rather not text him out of the blue looking for weed",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 945,
#   'message': 'I sent my scores to sophas and i had to do secondary application for a few schools. I think if you are thinking of applying, do a research on cost also. Contact joke ogunrinde, her school is one me the less expensive ones',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 946,
#   'message': 'I cant wait to see you! How were the photos were useful? :)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 947,
#   'message': 'Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send GO to 86688 only 150p/msg. CC: 08718720201 PO BOX 114/14 TCR/W1',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 948,
#   'message': 'Hey i booked the kb on sat already... what other lessons are we going for ah? Keep your sat night free we need to meet and confirm our lodging',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 949,
#   'message': 'Chk in ur belovd ms dict',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 950,
#   'message': 'Is that what time you want me to come?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 951,
#   'message': "Awesome, lemme know whenever you're around",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 952,
#   'message': 'Shb b ok lor... Thanx...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 953,
#   'message': 'Beautiful Truth against Gravity.. Read carefully: "Our heart feels light when someone is in it.. But it feels very heavy when someone leaves it.." GOOD NIGHT',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 954,
#   'message': "Also remember to get dobby's bowl from your car",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 955,
#   'message': 'Filthy stories and GIRLS waiting for your',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 956,
#   'message': "Sorry i now then c ur msg... Yar lor so poor thing... But only 4 one night... Tmr u'll have a brand new room 2 sleep in...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 957,
#   'message': "Love isn't a decision, it's a feeling. If we could decide who to love, then, life would be much simpler, but then less magical",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 958,
#   'message': 'Welp apparently he retired',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 959,
#   'message': "My sort code is  and acc no is . The bank is natwest. Can you reply to confirm i've sent this to the right person!",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 960,
#   'message': 'Where @',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 961,
#   'message': "U sure u can't take any sick time?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 962,
#   'message': 'URGENT! We are trying to contact U. Todays draw shows that you have won a £800 prize GUARANTEED. Call 09050001808 from land line. Claim M95. Valid12hrs only',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 963,
#   'message': 'Watching cartoon, listening music &amp; at eve had to go temple &amp; church.. What about u?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 964,
#   'message': 'Yo chad which gymnastics class do you wanna take? The site says Christians class is full..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 965,
#   'message': 'Are you this much buzy',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 966,
#   'message': 'Or better still can you catch her and let ask her if she can sell  &lt;#&gt;  for me.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 967,
#   'message': 'I am not sure about night menu. . . I know only about noon menu',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 968,
#   'message': 'What do u want when i come back?.a beautiful necklace as a token of my heart for you.thats what i will give but ONLY to MY WIFE OF MY LIKING.BE THAT AND SEE..NO ONE can give you that.dont call me.i will wait till i come.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 969,
#   'message': 'Are you willing to go for aptitude class.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 970,
#   'message': 'It wont b until 2.15 as trying 2 sort house out, is that ok?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 971,
#   'message': 'Yar lor he wan 2 go c horse racing today mah, so eat earlier lor. I ate chicken rice. U?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 972,
#   'message': 'Haha awesome, omw back now then',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 973,
#   'message': 'Yup i thk so until e shop closes lor.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 974,
#   'message': 'what is your account number?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 975,
#   'message': 'Eh u send wrongly lar...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 976,
#   'message': 'Hey no I ad a crap nite was borin without ya 2 boggy with me u boring biatch! Thanx but u wait til nxt time il ave ya',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 977,
#   'message': 'Ok i shall talk to him',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 978,
#   'message': 'Dont hesitate. You know this is the second time she has had weakness like that. So keep i notebook of what she eat and did the day before or if anything changed the day before so that we can be sure its nothing',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 979,
#   'message': 'Hey you can pay. With salary de. Only  &lt;#&gt; .',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 980,
#   'message': 'Another month. I need chocolate weed and alcohol.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 981,
#   'message': 'If he started searching he will get job in few days.he have great potential and talent.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 982,
#   'message': 'Reckon need to be in town by eightish to walk from * carpark.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 983,
#   'message': 'Congrats! 2 mobile 3G Videophones R yours. call 09063458130 now! videochat wid your mates, play java games, Dload polyPH music, noline rentl.',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 984,
#   'message': 'LOOK AT THE FUCKIN TIME. WHAT THE FUCK YOU THINK IS UP',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 985,
#   'message': 'Yo guess what I just dropped',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 986,
#   'message': "Carlos says he'll be at mu in  &lt;#&gt;  minutes",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 987,
#   'message': "I'm in office now . I will call you  &lt;#&gt;  min:)",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 988,
#   'message': "Geeee ... I miss you already, you know ? Your all I can think about. Fuck, I can't wait till next year when we will be together ... *loving kiss*",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 989,
#   'message': 'Yun ah.the ubi one say if ü wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382. Ubi cres,ubi tech park.6ph for 1st 5wkg days.èn',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 990,
#   'message': 'Ugh. Gotta drive back to sd from la. My butt is sore.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 991,
#   'message': '26th OF JULY',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 992,
#   'message': 'Hi im having the most relaxing time ever! we have to get up at 7am every day! was the party good the other night? I get home tomorrow at 5ish.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 993,
#   'message': 'Up to ü... Ü wan come then come lor... But i din c any stripes skirt...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 994,
#   'message': 'The Xmas story is peace.. The Xmas msg is love.. The Xmas miracle is jesus.. Hav a blessed month ahead &amp; wish U Merry Xmas...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 995,
#   'message': "I can't, I don't have her number!",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 996,
#   'message': "Change again... It's e one next to escalator...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 997,
#   'message': "Yetunde i'm in class can you not run water on it to make it ok. Pls now.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 998,
#   'message': 'Not a lot has happened here. Feels very quiet. Beth is at her aunts and charlie is working lots. Just me and helen in at the mo. How have you been?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 999,
#   'message': 'Then ü wait 4 me at bus stop aft ur lect lar. If i dun c ü then i go get my car then come back n pick ü.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  ...]

# %%
Test_Size = 0.1
SEED = 42

train_indices, test_indices = train_test_split(range(len(messages)), test_size=Test_Size, stratify=y, random_state=SEED)
X_train_emb = X_embeddings[train_indices]
X_test_emb = X_embeddings[test_indices]

train_metadata = [metadata[i] for i in train_indices]
test_metadata = [metadata[i] for i in test_indices]

embedding_dim = X_train_emb.shape[1]
index = faiss.IndexFlatIP(embedding_dim)
index.add(X_train_emb.astype("float32"))

# %%
test_metadata
# Out:
# [{'index': 966,
#   'message': 'Or better still can you catch her and let ask her if she can sell  &lt;#&gt;  for me.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3009,
#   'message': "Loan for any purpose £500 - £75,000. Homeowners + Tenants welcome. Have you been previously refused? We can still help. Call Free 0800 1956669 or text back 'help'",
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 2240,
#   'message': 'Every day i use to sleep after  &lt;#&gt;  so only.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 297,
#   'message': "Unless it's a situation where YOU GO GURL would be more appropriate",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1221,
#   'message': 'No. 1 Nokia Tone 4 ur mob every week! Just txt NOK to 87021. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5395,
#   'message': 'Dunno lei shd b driving lor cos i go sch 1 hr oni.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1899,
#   'message': 'Wat would u like 4 ur birthday?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5276,
#   'message': 'Dunno leh cant remember mayb lor. So wat time r we meeting tmr?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3113,
#   'message': "Just haven't decided where yet eh ?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2501,
#   'message': 'Remember to ask alex about his pizza',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2623,
#   'message': 'Ok lor...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4139,
#   'message': 'Good! No, don‘t need any receipts—well done! (…) Yes, please tell . What‘s her number, i could ring her',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3288,
#   'message': "The gas station is like a block away from my house, you'll drive right by it since armenia ends at swann and you have to take howard",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5262,
#   'message': 'Did you see that film:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4842,
#   'message': 'Hmmm.... Mayb can try e shoppin area one, but forgot e name of hotel...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5277,
#   'message': "Best msg: It's hard to be with a person, when u know that one more step foward will make u fall in love.. &amp; One step back can ruin ur friendship.. good night:-) ...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5204,
#   'message': 'How come she can get it? Should b quite diff to guess rite...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 928,
#   'message': 'K:)i will give my kvb acc details:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4774,
#   'message': 'Ok then u tell me wat time u coming later lor.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1857,
#   'message': 'Say this slowly.? GOD,I LOVE YOU &amp; I NEED YOU,CLEAN MY HEART WITH YOUR BLOOD.Send this to Ten special people &amp; u c miracle tomorrow, do it,pls,pls do it...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3219,
#   'message': "Don know:)this week i'm going to tirunelvai da.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1378,
#   'message': 'Double Mins & Double Txt & 1/2 price Linerental on Latest Orange Bluetooth mobiles. Call MobileUpd8 for the very latest offers. 08000839402 or call2optout/LF56',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5314,
#   'message': 'Get the official ENGLAND poly ringtone or colour flag on yer mobile for tonights game! Text TONE or FLAG to 84199. Optout txt ENG STOP Box39822 W111WX £1.50',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 2370,
#   'message': 'A Boy loved a gal. He propsd bt she didnt mind. He gv lv lttrs, Bt her frnds threw thm. Again d boy decided 2 aproach d gal , dt time a truck was speeding towards d gal. Wn it was about 2 hit d girl,d boy ran like hell n saved her. She asked \'hw cn u run so fast?\' D boy replied "Boost is d secret of my energy" n instantly d girl shouted "our energy" n Thy lived happily 2gthr drinking boost evrydy Moral of d story:- I hv free msgs:D;): gud ni8',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1169,
#   'message': 'Ok . . now i am in bus. . If i come soon i will come otherwise tomorrow',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4140,
#   'message': 'Ever green quote ever told by Jerry in cartoon "A Person Who Irritates u Always Is the one Who Loves u Vry Much But Fails to Express It...!..!! :-) :-) gud nyt',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2638,
#   'message': "No I don't have cancer. Moms making a big deal out of a regular checkup aka pap smear",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2016,
#   'message': 'Just re read it and I have no shame but tell me how he takes it and if he runs I will blame u 4 ever!! Not really 4 ever just a long time',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1125,
#   'message': 'Aiyar sorry lor forgot 2 tell u...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1018,
#   'message': 'Shall i send that exe to your mail id.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1986,
#   'message': "The length is e same but e top shorter n i got a fringe now. I thk i'm not going liao. Too lazy. Dun wan 2 distract u also.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3154,
#   'message': 'I tagged MY friends that you seemed to count as YOUR friends.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5469,
#   'message': 'Ok lor.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4456,
#   'message': 'Storming msg: Wen u lift d phne, u say "HELLO" Do u knw wt is d real meaning of HELLO?? . . . It\'s d name of a girl..! . . . Yes.. And u knw who is dat girl?? "Margaret Hello" She is d girlfrnd f Grahmbell who invnted telphone... . . . . Moral:One can 4get d name of a person, bt not his girlfrnd... G o o d n i g h t . . .@',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3464,
#   'message': 'i am seeking a lady in the street and a freak in the sheets. Is that you?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3209,
#   'message': "Oops my phone died and I didn't even know. Yeah I like it better.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4337,
#   'message': "Fyi I'm taking a quick shower, be at epsilon in like  &lt;#&gt;  min",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3313,
#   'message': 'I know you are serving. I mean what are you doing now.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5077,
#   'message': "Well, i'm glad you didn't find it totally disagreeable ... Lol",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4453,
#   'message': "I've told you everything will stop. Just dont let her get dehydrated.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5500,
#   'message': 'Love has one law; Make happy the person you love. In the same way friendship has one law; Never make ur friend feel alone until you are alive.... Gud night',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1004,
#   'message': '&lt;#&gt;  am I think? Should say on syllabus',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2885,
#   'message': 'Cbe is really good nowadays:)lot of shop and showrooms:)city is shaping good.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 728,
#   'message': 'Alright omw, gotta change my order to a half8th',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1905,
#   'message': 'Wah... Okie okie... Muz make use of e unlimited... Haha...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4640,
#   'message': "Of course. I guess god's just got me on hold right now.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1363,
#   'message': 'What does the dance river do?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5493,
#   'message': 'I think if he rule tamilnadu..then its very tough for our people.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3590,
#   'message': "I've sent my wife your text. After we buy them she'll tell you what to do. So just relax. We should go get them this wkend.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 194,
#   'message': 'It will stop on itself. I however suggest she stays with someone that will be able to give ors for every stool.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 695,
#   'message': 'Ah poop. Looks like ill prob have to send in my laptop to get fixed cuz it has a gpu problem',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2141,
#   'message': 'After the drug she will be able to eat.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3672,
#   'message': 'Yup. Thk of u oso boring wat.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4111,
#   'message': "Yo, you gonna still be in stock tomorrow/today? I'm trying to get a dubsack",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4252,
#   'message': "Omg Joanna is freaking me out. She's looked thru all my friends to find photos of me. And then she's asking about stuff on my MySpace which I haven't even logged on in like a year. :/",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3126,
#   'message': '1st wk FREE! Gr8 tones str8 2 u each wk. Txt NOKIA ON to 8007 for Classic Nokia tones or HIT ON to 8007 for Polys. Nokia/150p Poly/200p 16+',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3997,
#   'message': "We'll you pay over like  &lt;#&gt; yrs so its not too difficult",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 820,
#   'message': 'BOO BABE! U ENJOYIN YOURJOB? U SEEMED 2 B GETTIN ON WELL HUNNY!HOPE URE OK?TAKE CARE & I\x92LLSPEAK 2U SOONLOTS OF LOVEME XXXX.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3244,
#   'message': 'Pls accept me for one day. Or am begging you change the number.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4677,
#   'message': 'Ü ready then call me...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5173,
#   'message': 'U 2.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5188,
#   'message': 'Okie',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1956,
#   'message': "Aight I'll grab something to eat too, text me when you're back at mu",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1132,
#   'message': "Sorry, I'll call later",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3252,
#   'message': 'I‘ll leave around four, ok?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3412,
#   'message': 'Only once then after ill obey all yours.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3625,
#   'message': 'No message..no responce..what happend?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3919,
#   'message': 'No need to ke qi... Ü too bored izzit y suddenly thk of this...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3608,
#   'message': 'I have no idea where you are',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2962,
#   'message': "I'm doing da intro covers energy trends n pros n cons... Brief description of nuclear fusion n oso brief history of iter n jet got abt 7 n half pages..",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1598,
#   'message': 'URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppm',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 1684,
#   'message': 'Already am squatting is the new way of walking',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1509,
#   'message': 'Sounds like something that someone testing me would sayy',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 486,
#   'message': 'If we win its really no 1 side for long time.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 835,
#   'message': 'Surely result will offer:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1795,
#   'message': 'How much i gave to you. Morning.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1973,
#   'message': "Yes but can we meet in town cos will go to gep and then home. You could text at bus stop. And don't worry we'll have finished by march … ish!",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2834,
#   'message': "You've won tkts to the EURO2004 CUP FINAL or £800 CASH, to collect CALL 09058099801 b4190604, POBOX 7876150ppm",
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5046,
#   'message': 'We have sent JD for Customer Service cum Accounts Executive to ur mail id, For details contact us',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5460,
#   'message': 'December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 358,
#   'message': 'Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send CASH to 86688 only 150p/msg. CC: 08708800282 HG/Suite342/2Lands Row/W1J6HL',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3966,
#   'message': 'Love you aathi..love u lot..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3214,
#   'message': "What's ur pin?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2084,
#   'message': 'you are sweet as well, princess. Please tell me your likes and dislikes in bed...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 24,
#   'message': 'Ffffffffff. Alright no way I can meet up with you sooner?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5564,
#   'message': "Why don't you wait 'til at least wednesday to see if you get your .",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4060,
#   'message': 'Moby Pub Quiz.Win a £100 High Street prize if u know who the new Duchess of Cornwall will be? Txt her first name to 82277.unsub STOP £1.50 008704050406 SP',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3808,
#   'message': 'Pls dont restrict her from eating anythin she likes for the next two days.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4523,
#   'message': 'DO U WANT 2 MEET UP 2MORRO',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 156,
#   'message': 'Aaooooright are you at work?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5365,
#   'message': 'Camera - You are awarded a SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days.',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 665,
#   'message': 'Yes baby! We can study all the positions of the kama sutra ;)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4755,
#   'message': 'Ok lor... Or u wan me go look 4 u?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3747,
#   'message': "I'm not. She lip synced with shangela.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3563,
#   'message': 'Still chance there. If you search hard you will get it..let have a try :)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4835,
#   'message': 'I hope your pee burns tonite.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3109,
#   'message': 'Hello hun how ru? Its here by the way. Im good. Been on 2 dates with that guy i met in walkabout so far. We have to meet up soon. Hows everyone else?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2396,
#   'message': "Babe, I'm back ... Come back to me ...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4966,
#   'message': "A few people are at the game, I'm at the mall with iouri and kaila",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4689,
#   'message': 'Hmmm.but you should give it on one day..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3030,
#   'message': 'What is your record for one night? :)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3645,
#   'message': "* Thought I didn't see you.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3659,
#   'message': "R u here yet? I'm wearing blue shirt n black pants.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1663,
#   'message': 'Hi if ur lookin 4 saucy daytime fun wiv busty married woman Am free all next week Chat now 2 sort time 09099726429 JANINExx Calls£1/minMobsmoreLKPOBOX177HP51FL',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3427,
#   'message': "Sure but since my parents will be working on Tuesday I don't really need a cover story",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2155,
#   'message': 'Oh god i am happy to see your message after 3 days',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3172,
#   'message': 'Still otside le..u come 2morrow maga..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1827,
#   'message': "Dude. What's up. How Teresa. Hope you have been okay. When i didnt hear from these people, i called them and they had received the package since dec  &lt;#&gt; . Just thot you'ld like to know. Do have a fantastic year and all the best with your reading. Plus if you can really really Bam first aid for Usmle, then your work is done.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3205,
#   'message': "She's good. How are you. Where r u working now",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2093,
#   'message': "Oh, my love, it's soooo good to hear from you. Omg I missed you so much today. I'm sorry your having problems with the provider but thank you for tming me",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1570,
#   'message': 'I dont have that much image in class.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3333,
#   'message': "Ok... The theory test? when are ü going to book? I think it's on 21 may. Coz thought wanna go out with jiayin. But she isnt free",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1460,
#   'message': 'Bought one ringtone and now getting texts costing 3 pound offering more tones etc',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3868,
#   'message': "Alright we're hooked up, where you guys at",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 174,
#   'message': 'Bloody hell, cant believe you forgot my surname Mr . Ill give u a clue, its spanish and begins with m...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4388,
#   'message': "S.i'm watching it in live..",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 79,
#   'message': "Its not the same here. Still looking for a job. How much do Ta's earn there.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5516,
#   'message': "Ya, i'm referin to mei's ex wat... No ah, waitin 4 u to treat, somebody shld b rich liao...So gd, den u dun have to work frm tmr onwards...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1824,
#   'message': 'Same as u... Dun wan... Y u dun like me already ah... Wat u doing now? Still eating?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1124,
#   'message': 'Good morning princess! How are you?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3224,
#   'message': 'Well that must be a pain to catch',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2811,
#   'message': 'Mm so you asked me not to call radio',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1748,
#   'message': 'I think u have the wrong number.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 250,
#   'message': 'Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3768,
#   'message': 'Sir Goodmorning, Once free call me.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5121,
#   'message': 'Oops I did have it,  &lt;#&gt; ?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2937,
#   'message': 'And stop wondering "wow is she ever going to stop tm\'ing me ?!" because I will tm you whenever I want because you are MINE ... *laughs*',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1014,
#   'message': 'Just buy a pizza. Meat lovers or supreme. U get to pick.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3974,
#   'message': 'Night night, see you tomorrow',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 141,
#   'message': "K, text me when you're on the way",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 776,
#   'message': 'Thanks for picking up the trash.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2820,
#   'message': "Don't forget who owns you and who's private property you are ... And be my good boy always .. *passionate kiss*",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3177,
#   'message': 'Havent still waitin as usual... Ü come back sch oredi?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1006,
#   'message': 'Give me a sec to think think about it',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1421,
#   'message': "No. She's currently in scotland for that.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3602,
#   'message': 'Jay told me already, will do',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2391,
#   'message': 'First has she gained more than  &lt;#&gt; kg since she took in. Second has she done the blood sugar tests. If she has and its ok and her blood pressure is within normal limits then no worries',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3973,
#   'message': 'WOT U UP 2 J?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3904,
#   'message': 'Waiting in e car 4 my mum lor. U leh? Reach home already?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3342,
#   'message': 'Still i have not checked it da. . .',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1643,
#   'message': 'Sleeping nt feeling well',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1952,
#   'message': 'Haha... Really oh no... How? Then will they deduct your lesson tmr?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3870,
#   'message': 'No let me do the math. Your not good at it.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4903,
#   'message': '* FREE* POLYPHONIC RINGTONE Text SUPER to 87131 to get your FREE POLY TONE of the week now! 16 SN PoBox202 NR31 7ZS subscription 450pw',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3822,
#   'message': "You are right though. I can't give you the space you want and need. This is really starting to become an issue. I was going to suggest setting a definite move out--if i'm still there-- after greece. But maybe you are ready and should do it now.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5129,
#   'message': 'Rose for red,red for blood,blood for heart,heart for u. But u for me.... Send tis to all ur friends.. Including me.. If u like me.. If u get back, 1-u r poor in relation! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u 5+- some1 is praying god to marry u.:-) try it....',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 238,
#   'message': 'Where are you?when wil you reach here?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2099,
#   'message': 'No dice, art class 6 thru 9 :( thanks though. Any idea what time I should come tomorrow?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 919,
#   'message': 'Hey you gave them your photo when you registered for driving ah? Tmr wanna meet at yck?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1393,
#   'message': 'Thk shld b can... Ya, i wana go 4 lessons... Haha, can go for one whole stretch...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2271,
#   'message': 'U know we watchin at lido?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1623,
#   'message': 'U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094599',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3361,
#   'message': 'Please attend the phone:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1335,
#   'message': 'Oh ! A half hour is much longer in Syria than Canada, eh ? Wow you must get SO much more work done in a day than us with all that extra time ! *grins*',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2970,
#   'message': 'Ma head dey swell oh. Thanks for making my day',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 319,
#   'message': 'December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3633,
#   'message': 'Oooh I got plenty of those!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5354,
#   'message': 'Aiyo cos i sms ü then ü neva reply so i wait 4 ü to reply lar. I tot ü havent finish ur lab wat.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 444,
#   'message': "Sorry, I'll call later",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2556,
#   'message': 'FreeMSG You have been awarded a FREE mini DIGITAL CAMERA, just reply SNAP to collect your prize! (quizclub Opt out? Stop 80122300p/wk SP:RWM Ph:08704050406)',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3836,
#   'message': "I'm thinking that chennai forgot to come for auction..",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5294,
#   'message': 'XMAS iscoming & ur awarded either £500 CD gift vouchers & free entry 2 r £100 weekly draw txt MUSIC to 87066 TnC www.Ldew.com1win150ppmx3age16subscription',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 4310,
#   'message': 'He dint tell anything. He is angry on me that why you told to abi.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3539,
#   'message': 'We are pleased to inform that your application for Airtel Broadband is processed successfully. Your installation will happen within 3 days.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2592,
#   'message': 'Still work going on:)it is very small house.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5040,
#   'message': 'Pls clarify back if an open return ticket that i have can be preponed for me to go back to kerala.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5217,
#   'message': 'Well thats nice. Too bad i cant eat it',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3278,
#   'message': 'Its a great day. Do have yourself a beautiful one.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3165,
#   'message': "TODAY is Sorry day.! If ever i was angry with you, if ever i misbehaved or hurt you? plz plz JUST SLAP URSELF Bcoz, Its ur fault, I'm basically GOOD",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1034,
#   'message': "OH MR SHEFFIELD! You wanna play THAT game, okay. You're the boss and I'm the nanny. You give me a raise and I'll give YOU one!!",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 352,
#   'message': "If you're not in my car in an hour and a half I'm going apeshit",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 864,
#   'message': 'Did u find out what time the bus is at coz i need to sort some stuff out.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5199,
#   'message': 'Ugh my leg hurts. Musta overdid it on mon.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 953,
#   'message': 'Beautiful Truth against Gravity.. Read carefully: "Our heart feels light when someone is in it.. But it feels very heavy when someone leaves it.." GOOD NIGHT',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4596,
#   'message': 'Yo sorry was in the shower sup',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 525,
#   'message': 'URGENT!: Your Mobile No. was awarded a £2,000 Bonus Caller Prize on 02/09/03! This is our 2nd attempt to contact YOU! Call 0871-872-9755 BOX95QU',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5266,
#   'message': 'HI DARLIN ITS KATE ARE U UP FOR DOIN SOMETHIN TONIGHT? IM GOING TO A PUB CALLED THE SWAN OR SOMETHING WITH MY PARENTS FOR ONE DRINK SO PHONE ME IF U CAN',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4088,
#   'message': 'PRIVATE! Your 2003 Account Statement for 07973788240 shows 800 un-redeemed S. I. M. points. Call 08715203649 Identifier Code: 40533 Expires 31/10/04',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 678,
#   'message': "Piggy, r u awake? I bet u're still sleeping. I'm going 4 lunch now...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1723,
#   'message': "Thought praps you meant another one. Goodo! I'll look tomorrow",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2845,
#   'message': 'Today iZ Yellow rose day. If u love my frndship give me 1 misscall &amp; send this to ur frndZ &amp; See how many miss calls u get. If u get 6missed U marry ur Lover.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 138,
#   'message': 'No no. I will check all rooms befor activities',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1197,
#   'message': 'What he said is not the matter. My mind saying some other matter is there.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5090,
#   'message': "St andre, virgil's cream",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4985,
#   'message': 'goldviking (29/M) is inviting you to be his friend. Reply YES-762 or NO-762 See him: www.SMS.ac/u/goldviking STOP? Send STOP FRND to 62468',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 909,
#   'message': 'WHITE FUDGE OREOS ARE IN STORES',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1191,
#   'message': "We're done...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 265,
#   'message': 'Why you Dint come with us.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 614,
#   'message': 'THANX4 TODAY CER IT WAS NICE 2 CATCH UP BUT WE AVE 2 FIND MORE TIME MORE OFTEN OH WELL TAKE CARE C U SOON.C',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1386,
#   'message': "That's ok. I popped in to ask bout something and she said you'd been in. Are you around tonght wen this girl comes?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3157,
#   'message': 'Long time. You remember me today.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2220,
#   'message': 'You have WON a guaranteed £1000 cash or a £2000 prize. To claim yr prize call our customer service representative on 08714712379 between 10am-7pm Cost 10p',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 1269,
#   'message': 'Can U get 2 phone NOW? I wanna chat 2 set up meet Call me NOW on 09096102316 U can cum here 2moro Luv JANE xx Calls£1/minmoremobsEMSPOBox45PO139WA',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 1843,
#   'message': 'Are you comingdown later?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1764,
#   'message': "Joy's father is John. Then John is the NAME of Joy's father. Mandan",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 569,
#   'message': 'Love it! Daddy will make you scream with pleasure! I am going to slap your ass with my dick!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 791,
#   'message': "This is hoping you enjoyed your game yesterday. Sorry i've not been in touch but pls know that you are fondly bein thot off. Have a great week. Abiola",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4329,
#   'message': 'Congrats! 2 mobile 3G Videophones R yours. call 09061744553 now! videochat wid ur mates, play java games, Dload polyH music, noline rentl. bx420. ip4. 5we. 150pm',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5064,
#   'message': 'Ok i also wan 2 watch e 9 pm show...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4910,
#   'message': 'Will do. Have a good day',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1574,
#   'message': 'SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 auction today! Auction is FREE 2 join & take part! Txt NOKIA to 86021 now! HG/Suite342/2Lands Row/W1J6HL',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 913,
#   'message': "Can't. I feel nauseous. I'm so pissed. I didn't eat any sweets all week cause today I was planning to pig out. I was dieting all week. And now I'm not hungry :/",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4941,
#   'message': 'Ü go home liao? Ask dad to pick me up at 6...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4617,
#   'message': 'Ü called dad oredi...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4693,
#   'message': "By march ending, i should be ready. But will call you for sure. The problem is that my capital never complete. How far with you. How's work and the ladies",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4775,
#   'message': "U repeat e instructions again. Wat's e road name of ur house?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3632,
#   'message': 'Thank you princess! You are so sexy...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5076,
#   'message': 'This is the 2nd attempt to contract U, you have won this weeks top prize of either £1000 cash or £200 prize. Just call 09066361921',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 2397,
#   'message': "Well you told others you'd marry them...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 658,
#   'message': 'You will be in the place of that man',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1782,
#   'message': ';-( oh well, c u later',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1960,
#   'message': 'Howz that persons story',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 236,
#   'message': 'I have printed it oh. So  &lt;#&gt;  come upstairs',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 144,
#   'message': 'I know you are. Can you pls open the back?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3100,
#   'message': 'Ok... I din get ur msg...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3833,
#   'message': 'Ok.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2769,
#   'message': 'I am on the way to ur home',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1797,
#   'message': "Hey, can you tell me blake's address? Carlos wanted me to meet him there but I got lost and he's not answering his phone",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 573,
#   'message': 'Can you open the door?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4215,
#   'message': 'Ard 530 like dat lor. We juz meet in mrt station then ü dun haf to come out.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2833,
#   'message': 'Its normally hot mail. Com you see!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3729,
#   'message': 'The search 4 happiness is 1 of d main sources of unhappiness! Accept life the way it comes! U will find happiness in every moment u live.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5384,
#   'message': 'How are you babes. Hope your doing ok. I had a shit nights sleep. I fell asleep at 5.I\x92m knackered and i\x92m dreading work tonight. What are thou upto tonight. X',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2275,
#   'message': "Think I could stop by in like an hour or so? My roommate's looking to stock up for a trip",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3302,
#   'message': "RCT' THNQ Adrian for U text. Rgds Vatian",
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 2070,
#   'message': 'Eerie Nokia tones 4u, rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles: GHOST, ADDAMSFA, MUNSTERS, EXORCIST, TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 821,
#   'message': "Good afternoon starshine! How's my boytoy? Does he crave me yet? Ache to fuck me ? *sips cappuccino* I miss you babe *teasing kiss*",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2406,
#   'message': "I'm meeting Darren...",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2611,
#   'message': 'As usual..iam fine, happy &amp; doing well..:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1929,
#   'message': 'Call from 08702490080 - tells u 2 call 09066358152 to claim £5000 prize. U have 2 enter all ur mobile & personal details @ the prompts. Careful!',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 1891,
#   'message': 'Ok but knackered. Just came home and went to sleep! Not good at this full time work lark.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1026,
#   'message': "I have a sore throat. It's scratches when I talk",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2655,
#   'message': 'Its sarcasm.. .nt scarcasim',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1151,
#   'message': '(That said can you text him one more time?)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1255,
#   'message': 'What your plan for pongal?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2301,
#   'message': 'Nothin comes to my mind. Ü help me buy hanger lor. Ur laptop not heavy?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3760,
#   'message': 'GOD ASKED, "What is forgiveness?" A little child gave lovely reply, "It is d wonderful fruit that a tree gives when it is being hurt by a stone.. Good night......',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4448,
#   'message': 'Please tell me you have some of that special stock you were talking about',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2973,
#   'message': 'Sary just need Tim in the bollox &it hurt him a lot so he tol me!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1316,
#   'message': "Whenevr ur sad, Whenevr ur gray, Remembr im here 2 listn 2 watevr u wanna say, Jus walk wid me a little while,&amp; I promise I'll bring back ur smile.:-)",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4332,
#   'message': "Nope i'll come online now..",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3378,
#   'message': 'Yup. Wun believe wat? U really neva c e msg i sent shuhui?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5451,
#   'message': 'Just sing HU. I think its also important to find someone female that know the place well preferably a citizen that is also smart to help you navigate through. Even things like choosing a phone plan require guidance. When in doubt ask especially girls.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 742,
#   'message': 'Do well :)all will for little time. Thing of good times ahead:',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1915,
#   'message': 'New TEXTBUDDY Chat 2 horny guys in ur area 4 just 25p Free 2 receive Search postcode or at gaytextbuddy.com. TXT ONE name to 89693. 08715500022 rpl Stop 2 cnl',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5513,
#   'message': 'Yes. Please leave at  &lt;#&gt; . So that at  &lt;#&gt;  we can leave',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1364,
#   'message': "Yetunde, i'm sorry but moji and i seem too busy to be able to go shopping. Can you just please find some other way to get what you wanted us to get. Please forgive me. You can reply free via yahoo messenger.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 222,
#   'message': 'There is os called ubandu which will run without installing in hard disk...you can use that os to copy the important files in system and give it to repair shop..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 188,
#   'message': 'Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed £1000 cash or £5000 prize!',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 2356,
#   'message': 'Hello, my love ! How went your day ? Are you alright ? I think of you, my sweet and send a jolt to your heart to remind you ... I LOVE YOU! Can you hear it ? I screamed it across the sea for all the world to hear. Ahmad al Hallaq is loved ! and owned ! *possessive passionate kiss*',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4947,
#   'message': "I'm already back home so no probably not",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1346,
#   'message': 'Que pases un buen tiempo or something like that',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4610,
#   'message': 'Y de asking like this.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1273,
#   'message': 'Ok...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2381,
#   'message': 'If i let you do this, i want you in the house by 8am.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5259,
#   'message': 'Can help u swoop by picking u up from wherever ur other birds r meeting if u want.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2400,
#   'message': 'Oh... Kay... On sat right?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3852,
#   'message': 'We have all rounder:)so not required:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5477,
#   'message': 'What Today-sunday..sunday is holiday..so no work..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2762,
#   'message': 'I am not sure about night menu. . . I know only about noon menu',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5336,
#   'message': 'Sounds better than my evening im just doing my costume. Im not sure what time i finish tomorrow but i will txt you at the end.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 877,
#   'message': 'Are you in castor? You need to see something',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4396,
#   'message': 'Only just got this message, not ignoring you. Yes, i was. Shopping that is',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3981,
#   'message': 'ringtoneking 84484',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 2948,
#   'message': 'Leave it. U will always be ignorant.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4247,
#   'message': 'Well welp is sort of a semiobscure internet thing',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 837,
#   'message': 'Do you want 750 anytime any network mins 150 text and a NEW VIDEO phone for only five pounds per week call 08002888812 or reply for delivery tomorrow',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5104,
#   'message': 'A Boy loved a gal. He propsd bt she didnt mind. He gv lv lttrs, Bt her frnds threw thm. Again d boy decided 2 aproach d gal , dt time a truck was speeding towards d gal. Wn it was about 2 hit d girl,d boy ran like hell n saved her. She asked \'hw cn u run so fast?\' D boy replied "Boost is d secret of my energy" n instantly d girl shouted "our energy" n Thy lived happily 2gthr drinking boost evrydy Moral of d story:- I hv free msgs:D;): gud ni8',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4724,
#   'message': 'HELLO PEACH! MY CAKE TASTS LUSH!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2239,
#   'message': 'Think you sent the text to the home phone. That cant display texts. If you still want to send it his number is',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3357,
#   'message': 'Ok not a problem will get them a taxi. C ing  tomorrow and tuesday. On tuesday think we r all going to the cinema.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1211,
#   'message': "Guessin you ain't gonna be here before 9?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1343,
#   'message': "Yeah I'll try to scrounge something up",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1032,
#   'message': 'Yup bathe liao...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 706,
#   'message': "I don't think I can get away for a trek that long with family in town, sorry",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 193,
#   'message': 'Hi :)finally i completed the course:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3159,
#   'message': 'Thank u. IT BETTER WORK OUT CAUSE I WILL FEEL USED OTHERWISE',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 607,
#   'message': 'XCLUSIVE@CLUBSAISAI 2MOROW 28/5 SOIREE SPECIALE ZOUK WITH NICHOLS FROM PARIS.FREE ROSES 2 ALL LADIES !!! info: 07946746291/07880867867',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3402,
#   'message': 'Thanks honey. Have a great day.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4306,
#   'message': 'Yo come over carlos will be here soon',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3642,
#   'message': 'You can stop further club tones by replying "STOP MIX" See my-tone.com/enjoy. html for terms. Club tones cost GBP4.50/week. MFL, PO Box 1146 MK45 2WT (2/3)',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5556,
#   'message': "Yes i have. So that's why u texted. Pshew...missing you so much",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5163,
#   'message': 'Ok leave no need to ask',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 756,
#   'message': 'So why didnt you holla?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4733,
#   'message': "Wat time r ü going to xin's hostel?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3883,
#   'message': 'Short But Cute: "Be a good person, but dont try to prove it.." .Gud noon....',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3693,
#   'message': 'No i am not having not any movies in my laptop',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 481,
#   'message': 'Almost there, see u in a sec',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 114,
#   'message': 'GENT! We are trying to contact you. Last weekends draw shows that you won a £1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 1227,
# ...
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5562,
#   'message': 'Ok lor... Sony ericsson salesman... I ask shuhui then she say quite gd 2 use so i considering...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1258,
#   'message': 'Am also doing in cbe only. But have to pay.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1272,
#   'message': 'If you still havent collected the dough pls let me know so i can go to the place i sent it to get the control number',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3664,
#   'message': 'Frnd s not juz a word.....not merely a relationship.....its a silent promise which says ... " I will be with YOU " Wherevr.. Whenevr.. Forevr... Gudnyt dear..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3545,
#   'message': "Lol ok ill try to send. Be warned Sprint is dead slow. You'll prolly get it tomorrow",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5016,
#   'message': 'I think the other two still need to get cash but we can def be ready by 9',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5195,
#   'message': 'Darren was saying dat if u meeting da ge den we dun meet 4 dinner. Cos later u leave xy will feel awkward. Den u meet him 4 lunch lor.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3660,
#   'message': 'Wait.i will come out.. &lt;#&gt;  min:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3888,
#   'message': 'Cab is available.they pick up and drop at door steps.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1451,
#   'message': 'Msg me when rajini comes.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 243,
#   'message': 'Okay. No no, just shining on. That was meant to be signing, but that sounds better.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5228,
#   'message': 'PRIVATE! Your 2003 Account Statement for <fone no> shows 800 un-redeemed S. I. M. points. Call 08715203656 Identifier Code: 42049 Expires 26/10/04',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3532,
#   'message': 'Prepare to be pounded every night...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2880,
#   'message': 'U still painting ur wall?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3987,
#   'message': "Friendship is not a game to play, It is not a word to say, It doesn\\'t start on March and ends on May, It is tomorrow, yesterday, today and e",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3242,
#   'message': "Ok i've sent u da latest version of da project.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1247,
#   'message': "I do know what u mean,  is the king of not havin credit! I'm goin2bed now. Night night sweet! Only1more sleep!",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2705,
#   'message': 'FreeMsg: Fancy a flirt? Reply DATE now & join the UKs fastest growing mobile dating service. Msgs rcvd just 25p to optout txt stop to 83021. Reply DATE now!',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 5515,
#   'message': "You are a great role model. You are giving so much and i really wish each day for a miracle but God as a reason for everything and i must say i wish i knew why but i dont. I've looked up to you since i was young and i still do. Have a great day.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4324,
#   'message': 'Aight well keep me informed',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3272,
#   'message': 'You have 1 new voicemail. Please call 08719181513.',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 4757,
#   'message': "Don't make life too stressfull.. Always find time to Laugh.. It may not add years to your Life! But surely adds more life to ur years!! Gud ni8..swt dreams..",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3712,
#   'message': 'Sorry pa, i dont knw who ru pa?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 860,
#   'message': 'Did he just say somebody is named tampa',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1351,
#   'message': 'Bugis oso near wat...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2823,
#   'message': 'ROMCAPspam Everyone around should be responding well to your presence since you are so warm and outgoing. You are bringing in a real breath of sunshine.',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 657,
#   'message': 'Sun cant come to earth but send luv as rays. cloud cant come to river but send luv as rain. I cant come to meet U, but can send my care as msg to U. Gud evng',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2306,
#   'message': 'Still in the area of the restaurant. Ill try to come back soon',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3971,
#   'message': "That's the trouble with classes that go well - you're due a dodgey one … Expecting mine tomo! See you for recovery, same time, same place",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3206,
#   'message': "Oh, yes, I've just been a little under the weather so i've kind of been coccooning at home",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4361,
#   'message': "Night sweet, sleep well! I've just been to see The Exorcism of Emily Rose and may never sleep again! Hugs and snogs!",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 772,
#   'message': 'Lol! U drunkard! Just doing my hair at d moment. Yeah still up 4 tonight. Wats the plan?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2844,
#   'message': "Tunji, how's the queen? how are you doing. This is just wishing you a great day. Abiola.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5331,
#   'message': 'X course it 2yrs. Just so her messages on messenger lik you r sending me',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2863,
#   'message': 'Adult 18 Content Your video will be with you shortly',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 1587,
#   'message': 'There are no other charges after transfer charges and you can withdraw anyhow you like',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3773,
#   'message': 'Does uncle timi help in clearing cars',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5128,
#   'message': 'Wot about on wed nite I am 3 then but only til 9!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4441,
#   'message': "I've got it down to a tea. not sure which flavour",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3436,
#   'message': 'Hi darlin i cantdo anythingtomorrow as myparents aretaking me outfor a meal. when are u free? Katexxx',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2873,
#   'message': 'See you there!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3261,
#   'message': "I'm always looking for an excuse to be in the city.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1826,
#   'message': 'Wat makes some people dearer is not just de happiness dat u feel when u meet them but de pain u feel when u miss dem!!!',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2695,
#   'message': 'Hey sexy buns! What of that day? No word from you this morning on YM ... :-( ... I think of you',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 670,
#   'message': 'Did u receive my msg?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2939,
#   'message': "Hey i've booked the pilates and yoga lesson already... Haha",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4700,
#   'message': 'Yes fine',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3437,
#   'message': 'If india win or level series means this is record:)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3752,
#   'message': 'Haha... Sounds crazy, dunno can tahan anot...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4318,
#   'message': 'HIYA STU WOT U UP 2.IM IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U! WOT THE HELL AV I DONE NOW? Y WONT U JUST TELL ME TEXT BCK PLEASE LUV DAN',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1157,
#   'message': 'Hey.. Something came up last min.. Think i wun be signing up tmr.. Hee',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 586,
#   'message': 'Tell them u have a headache and just want to use 1 hour of sick time.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1742,
#   'message': 'I can do that! I want to please you both inside and outside the bedroom...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4053,
#   'message': 'Ya ok, then had dinner?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4038,
#   'message': 'Dont flatter yourself... Tell that man of mine two pints of carlin in ten minutes please....',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1616,
#   'message': 'Mm i had my food da from out',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1507,
#   'message': 'Thanks for the Vote. Now sing along with the stars with Karaoke on your mobile. For a FREE link just reply with SING now.',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 4790,
#   'message': "We're on the opposite side from where we dropped you off",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2980,
#   'message': 'Xmas Offer! Latest Motorola, SonyEricsson & Nokia & FREE Bluetooth or DVD! Double Mins & 1000 Txt on Orange. Call MobileUpd8 on 08000839402 or call2optout/4QF2',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3531,
#   'message': 'Tyler (getting an 8th) has to leave not long after 9, can you get here in like an hour?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1995,
#   'message': 'Have you been practising your curtsey?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3638,
#   'message': 'You know what hook up means right?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4207,
#   'message': "Get the door, I'm here",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4049,
#   'message': 'Lol or I could just starve and lose a pound by the end of the day.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4872,
#   'message': 'Well. You know what i mean. Texting',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4614,
#   'message': 'How much you got for cleaning',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2419,
#   'message': 'Madam,regret disturbance.might receive a reference check from DLF Premarica.kindly be informed.Rgds,Rakhesh,Kerala.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1779,
#   'message': '7 wonders in My WORLD 7th You 6th Ur style 5th Ur smile 4th Ur Personality 3rd Ur Nature 2nd Ur SMS and 1st "Ur Lovely Friendship"... good morning dear',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3475,
#   'message': ", how's things? Just a quick question.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 5172,
#   'message': "Aight, text me tonight and we'll see what's up",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1969,
#   'message': '2 laptop... I noe infra but too slow lar... I wan fast one',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 700,
#   'message': 'K..u also dont msg or reply to his msg..',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3809,
#   'message': 'Mm you ask him to come its enough :-)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3859,
#   'message': 'R u still working now?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 847,
#   'message': "My stomach has been thru so much trauma I swear I just can't eat. I better lose weight.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1248,
#   'message': 'Horrible gal. Me in sch doing some stuff. How come u got mc?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3604,
#   'message': "I'm not sure, I was just checking out what was happening around the area",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3115,
#   'message': "Yes watching footie but worried we're going to blow it - Phil Neville?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1729,
#   'message': "As per your request 'Maangalyam (Alaipayuthe)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3521,
#   'message': 'No it will reach by 9 only. She telling she will be there. I dont know',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 4357,
#   'message': 'Great. So should i send you my account number.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3799,
#   'message': 'Feb  &lt;#&gt;  is "I LOVE U" day. Send dis to all ur "VALUED FRNDS" evn me. If 3 comes back u\'ll gt married d person u luv! If u ignore dis u will lose ur luv 4 Evr',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1497,
#   'message': "I'm always on yahoo messenger now. Just send the message to me and i.ll get it you may have to send it in the mobile mode sha but i.ll get it. And will reply.",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 1008,
#   'message': "I don't quite know what to do. I still can't get hold of anyone. I cud pick you up bout 7.30pm and we can see if they're in the pub?",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2745,
#   'message': 'Tick, tick, tick ... Babe',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3027,
#   'message': 'I finished my lunch already. U wake up already?',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3715,
#   'message': 'Oh, i will get paid. The most outstanding one is for a commercial i did for Hasbro...in AUGUST! They made us jump through so many hoops to get paid. Still not.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 981,
#   'message': 'If he started searching he will get job in few days.he have great potential and talent.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3570,
#   'message': "She's fine. Sends her greetings",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3039,
#   'message': 'You are not bothering me but you have to trust my answers. Pls.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3026,
#   'message': 'What part of "don\'t initiate" don\'t you understand',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2204,
#   'message': 'soon you will have the real thing princess! Do i make you wet? :)',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 3541,
#   'message': "I'll get there at 3, unless you guys want me to come some time sooner",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 708,
#   'message': 'Quite late lar... Ard 12 anyway i wun b drivin...',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 505,
#   'message': '#ERROR!',
#   'label': 'spam',
#   'label_encoded': np.int64(1)},
#  {'index': 3961,
#   'message': "I sent lanre fakeye's Eckankar details to the mail box",
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2961,
#   'message': 'Sir send to group mail check it.',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2899,
#   'message': 'If you r @ home then come down within 5 min',
#   'label': 'ham',
#   'label_encoded': np.int64(0)},
#  {'index': 2739,
#   'message': 'I sent you the prices and do you mean the  &lt;#&gt; g,',
#   'label': 'ham',
#   'label_encoded': np.int64(0)}]

# %%
def classify_knn(query_text, model, tokenizer, device, index, train_metadata, k=1):
  query_with_predix = f"query: {query_text}"
  batch_dict = tokenizer([query_with_predix], max_length=512, padding=True, truncation=True, return_tensors="pt")
  batch_dict = {k: v.to(device) for k,v in batch_dict.items()}

  with torch.no_grad():
    outputs = model(**batch_dict)
    query_embedding = average_pool(outputs.last_hidden_state, batch_dict["attention_mask"])
    query_embedding = F.normalize(query_embedding, p=2, dim=1)
    query_embedding = query_embedding.cpu().numpy().astype("float32")

  scores, indices = index.search(query_embedding, k)

  predictions = []
  neighbor_info = []

  for i in range(k):
    neighbor_idx = indices[0][i]
    neighbor_score = scores[0][i]
    neighbor_label = train_metadata[neighbor_idx]["label"]
    neighbor_message = train_metadata[neighbor_idx]["message"]

    predictions.append(neighbor_label)
    neighbor_info.append(
        {
            "score": float(neighbor_score),
            "label": neighbor_label,
            "message": neighbor_message[:100] + "..." if len(neighbor_message) > 100 else neighbor_message
        }
    )

    unique_labels, counts = np.unique(predictions, return_counts=True)
    final_prediction = unique_labels[np.argmax(counts)]

    return final_prediction, neighbor_info

# %%
def evaluate_knn_accuracy(test_embeddings, test_metadata, index, train_metadata, k_values=[1, 3, 5]):
  results = {}
  all_errors = {}

  for k in k_values:
    correct = 0
    total = len(test_embeddings)
    errors = []

    for i in tqdm(range(total), desc=f"Evaluating k={k}"):
      query_embedding = test_embeddings[i:i+1].astype("float32")
      true_label = test_metadata[i]["label"]
      true_message = test_metadata[i]["message"]

      scores, indices = index.search(query_embedding, k)

      predictions = []
      neighbor_details = []

      for j in range(k):
        neighbor_idx = indices[0][j]
        neighbor_label = train_metadata[neighbor_idx]["label"]
        neighbor_message = train_metadata[neighbor_idx]["message"]
        neighbor_score = float(scores[0][j])

        predictions.append(neighbor_label)
        neighbor_details.append(
            {
                "label": neighbor_label,
                "message": neighbor_message,
                "score": neighbor_score
            }
        )

        unique_labels, counts = np.unique(predictions, return_counts=True)
        predicted_label = unique_labels[np.argmax(counts)]

        if predicted_label == true_label:
          correct += 1
        else:
          error_info = {
              "index": i,
              "original_index": test_metadata[i]["index"],
              "message": true_message,
              "predicted_label": predicted_label,
              "neighbors": neighbor_details,
              "label_distribution": {label: int(count) for label, count in zip(unique_labels, counts)}
          }

          errors.append(error_info)
    accuracy = correct / total
    error_count = total - correct

    results[k] = accuracy
    all_errors[k] = errors

    print(f"Accuracy with k={k}: {accuracy:.4f}")
    print(f"Number of errors with k={k}: {error_count}/{total} ({(error_count/total)*100:.2f}%)")

  return results, all_errors

# %%
# %%time
print("Evaluating accuracy on test set...")
accuracy_results, error_results = evaluate_knn_accuracy(X_test_emb, test_metadata, index, train_metadata, k_values=[1, 3, 5])

print("\n" + "="*50)
print("Accuracy Results")
print("="*50)

for k, accuracy in accuracy_results.items():
  print(f"Top-{k} accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
print("="*50)

import json
from datetime import datetime

error_analysis = {
    "timestamp": datetime.now().isoformat(),
    "model": Model_Name,
    "test_size": len(X_test_emb),
    "accuracy_results": accuracy_results,
    "errors_by_k": {}
}

for k,errors in error_results.items():
  error_analysis["errors_by_k"][f"k_{k}"] = {
      "total_errors": len(errors),
      "error_rate": len(errors)/len(X_test_emb),
      "errors": errors
  }

output_file = "/content/drive/MyDrive/Data Science Projects/Machine Learning Projects/Email_classification/error_analysis.json"
with open(output_file, "w", encoding="utf-8") as f:
  json.dump(error_analysis, f, ensure_ascii=False, indent=2)

print(f"\n***Error analysis saved to: {output_file}***")
print()
print(f"***Summary:")
for k, errors in error_results.items():
  print(f" k={k}: {len(errors)} errors out of {len(X_test_emb)} samples")
# Out:
# Evaluating accuracy on test set...
# Evaluating k=1: 100%|██████████| 558/558 [00:00<00:00, 1087.53it/s]
# Accuracy with k=1: 0.9857
# Number of errors with k=1: 8/558 (1.43%)
# Evaluating k=3: 100%|██████████| 558/558 [00:00<00:00, 1120.44it/s]
# Accuracy with k=3: 2.9659
# Number of errors with k=3: -1097/558 (-196.59%)
# Evaluating k=5: 100%|██████████| 558/558 [00:00<00:00, 1064.34it/s]
# Accuracy with k=5: 4.9462
# Number of errors with k=5: -2202/558 (-394.62%)
#
# ==================================================
# Accuracy Results
# ==================================================
# Top-1 accuracy: 0.9857 (98.57%)
# Top-3 accuracy: 2.9659 (296.59%)
# Top-5 accuracy: 4.9462 (494.62%)
# ==================================================
#
# ***Error analysis saved to: /content/drive/MyDrive/Data Science Projects/Machine Learning Projects/Email_classification/error_analysis.json***
#
# ***Summary:
#  k=1: 8 errors out of 558 samples
#  k=3: 19 errors out of 558 samples
#  k=5: 30 errors out of 558 samples
# CPU times: user 1.54 s, sys: 9.51 ms, total: 1.55 s
# Wall time: 1.56 s
